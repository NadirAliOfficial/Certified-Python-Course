# %%
import pandas as pd
data = pd.read_csv("data.csv")
data2 = pd.read_csv('employees.csv')

data2
avg = data2['Salary'].mean()
# data2.fillna(avg, inplace=True)
# data2
data2.dropna()
data['Name']
data
# Out:
#          Name  Age    City  Salary
# 0   Nadir Ali   20  Sukkur   10000
# 1  Irshad Ali   44     KHI   20000
# 2      Farman   34     ISB    3000

# %%
data.Age.mean()
data
# Out:
#          Name  Age    City  Salary
# 0   Nadir Ali   20  Sukkur   10000
# 1  Irshad Ali   44     KHI   20000
# 2      Farman   34     ISB    3000

# %% [markdown]
# <h1>This is Heading 1</h1>

# %%
import numpy as np
num = np.random.randint(1,10, size=3)
data['Exp'] = num
data
# Out:
#          Name  Age    City  Salary  Exp
# 0   Nadir Ali   20  Sukkur   10000    5
# 1  Irshad Ali   44     KHI   20000    4
# 2      Farman   34     ISB    3000    8

# %%
stu = pd.read_csv('stuData.csv')
df = pd.DataFrame(newStu)
stu.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 stu = pd.read_csv('stuData.csv')
# ----> 2 df = pd.DataFrame(newStu)
#       3 stu.head()
#
# NameError: name 'newStu' is not defined

# %%
newStu = pd.read_csv('/home/nak/Downloads/LvWaCg.csv')

df.dropna( inplace=True)
df.isnull().sum()
CGPA =df.groupby('Grade')['GPA'].mean()
age =df.groupby('Grade')['Age'].mean()
value =df['Grade'].value_counts()
age.sort_index()
print('This is by CGPA', CGPA)
print('This is by Age', age)
grade = value.plot(kind='bar', figsize=(4,2))
gpa = df['GPA'].plot(kind='bar', figsize=(4,2))
grade
# Out:
# This is by CGPA Grade
# A    2.765789
# B    2.793824
# C    2.924000
# D    2.643548
# F    2.706000
# Name: GPA, dtype: float64
# This is by Age Grade
# A    18.000000
# B    18.088235
# C    17.857143
# D    18.258065
# F    18.200000
# Name: Age, dtype: float64
# <Axes: xlabel='Grade'>

# %%
stu
# Out:
#      Student_ID First_Name Last_Name Grade  Age Enrollment_Date  \
# 0          3101       Emma     Scott     D   17      2017-10-01
# 1          3102    William    Turner     A   18      2020-02-24
# 2          3103      Lucas      Hill     F   18      2020-12-13
# 3          3104     Sophia    Wright     F   22      2022-04-22
# 4          3105       Liam  Anderson     B   18      2020-09-02
# ..          ...        ...       ...   ...  ...             ...
# 145        3246      Lucas     Young     C   20      2018-02-19
# 146        3247    William   Stewart     D   20      2023-04-02
# 147        3248     Olivia  Anderson     F   20      2018-02-19
# 148        3249      Lucas   Stewart     A   16      2018-11-15
# 149        3250     Olivia   Stewart     C   22      2019-06-09
#
#                 Major   GPA
# 0         Engineering  3.20
# 1          Psychology  2.05
# 2    Computer Science  3.71
# 3         Engineering  3.17
# 4                 Art  2.10
# ...
